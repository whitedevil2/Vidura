# %%
## Import Libraries and Load Data

import pandas as pd
import numpy as np
import random
from tqdm import tqdm
from gensim.models import Word2Vec 
import gensim.downloader as api
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize 
import nltk
import re
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
# Out:
# c:\users\home\appdata\local\programs\python\python37-32\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
data=pd.read_csv("dataset/rajyasabha_questions_and_answers_2009.csv")

# %%
data['question_title'] = data['question_title'].str.replace(" ","")
descriptions = data['question_title']

# %% [markdown]
# <h1>Formatting the Data</h1>
# In order to train a word2vec model, all of the description data will need to be concatenated into one giant string.

# %%
corpus_raw = ""
for description in descriptions:
    corpus_raw += description
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# Next, we need to tokenize the word corpus using NLTK. This process will essentially break the word corpus into an array of sentences stripping out less usefull characters like commas and hyphens in the process. In this way, we are able to train the word2vec model with the context of sentences and relative word placement.

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))
print(sentences)
# Out:
# [['SPURTINPRICESOFGOLD', 'OPENINGOFTRADECENTRESINLATINAMERICANCOUNTRIES', 'EARLYEXITOFCHINESEBUSINESSMENFROMTRADEFAIR', 'DONATIONBYSTCANDMMTCTOSTUDENTWINGSOFPOLITICALPARTIES', 'ENVISAGEDEXPORTEARNINGTARGETS', 'REQUESTSFORDENOTIFYINGAPPROVEDSEZS', 'TRADEBETWEENINDIAANDRUSSIA', 'SEZSINMAHARASHTRA', 'DONATIONBYSTCMMTCTONSUI', 'ANTIDUMPINGCASESREGISTEREDBYDGAD', 'EXPORTOFRICEANDVEGETABLES', 'MECHANISMTOREGULATEIMPORTEDGMPACKAGEDFOODS', 'INDIANPRODUCTSUNCOMPETITIVEINWORLDMARKET', 'RELIEFPACKAGETOEXPORTERSEXTENSIONOFTIMETODEVELOPERSOFSEZS', 'THMINISTERIALCONFERENCEOFWTOATGENEVA', 'SEZSCONVERTEDINTOCOMMERCIALREALESTATEOPERATIONS', 'FINANCIALASSISTANCETOTEAEXPORTERS', 'INTERNATIONALPOLICYNETWORKREPORTSONFAKEMEDICINES', 'NEWFOREIGNTRADEPOLICY', 'MINORITYSTATUSFORCENTRALUNIVERSITIES', 'MODERNIZATIONOFAUTONOMOUSMINORITYCOLLEGES', 'MINIMUMMARKSFORJEE', 'SEATSFORDISADVANTAGEDCHILDRENINMINORITYSCHOOLS', 'VISVABHARATIUNIVERSITY', 'CENTRALUNIVERSITIESINNORTHEASTERNSTATES', 'SETTINGUPOFCENTRALMADARSABOARD', 'CENTRALUNIVERSITYOFKORAPUT', 'INTRODUCTIONOFPOLYMERCURRENCY', 'PROMOTIONOFFOREIGNBREEDOFCOWS', 'MARINEFISHERIESREGULATIONANDMANAGEMENTACT', 'USEOFHORMONEINJECTIONTOINCREASEMILK', 'MODELCOLLEGESINEDUCATIONALLYBACKWARDDISTRICTS', 'INFORMATIONSOUGHTUNDERRTIACTFROMCHAUDHARYCHARANSINGHUNIVERSITY', 'INTERESTSUBSIDYONEDUCATIONALLOANS', 'IMPACTOFDROUGHTONRABICROP', 'APPOINTMENTOFJUDGESINHIGHERJUDICIARYNATIONALJUDICIALCOMMISSIONCOMPUTERISATIONOFOFFICIALLANGAUGELEGISLATIVECOMMISSIONOFKERALAAPPOINTMENTOFJUDGESSETTINGUPOFEVENINGCOURTSDISEASESINANIMALSCORRUPTIONINDMS', 'PERSONSWITHTECHNICALEDUCATION', 'DAIRYDEVELOPMENTPROJECTSINMADHYAPRADESH', 'SMUGGLINGOFCATTLEDEEPSEAFISHING', 'INSURANCESCHEMEFORFISHERMEN', 'PROPOSALSFROMMADHYAPRADESHFORPUREMILKPRODUCTION', 'OUTOFSCHOOLCHILDRENINABSENCEOFCRECHEFACILITIESMOBILESCHOOLSFORSCSSTS', 'REVIVALPLANFORIDPLPRICEOFMEDICINEFORSWINEFLU', 'ESTABLISHMENTOFPCPIR', 'REMOVALOFTOXICWASTEGENERATEDBYUNIONCARBIDEPRICEVARIATIONOFDRUGSAIDFORBHOPALGASTRAGEDYCOMMONCODEOFETHICSFORPHARMACEUTICALINDUSTRY', 'OVERCHARGINGOFMEDICINES', 'SALEOFANTIASTHMADRUGSATHIGHERPRICES', 'COMMITTEETOREVIEWPRICECONTROLMECHANISMOFMEDICINESCOMPENSATIONTOBHOPALGASTRAGEDYVICTIMSSALEOFDRUGSATHIGHPRICESISSUEOFPRICEFIXATIONOFDRUGS', 'ANNUALGROWTHRATEINPHARMACEUTICALINDUSTRY', 'MEMORANDUMREGARDINGBHOPALGASLEAKDISASTERIMPORTEDFINISHEDMEDICINESACQUISITIONOFPHARMAUNITSBYMULTINATIONALCOMPANIES', 'PHARMACEUTICALTECHNOLOGYUPGRADATIONASSISTANCESCHEMEIMPORTOFPULSES', 'BLACKMARKETINGOFESSENTIALCOMMODITIES', 'PRICERISEOFESSENTIALCOMMODITIES', 'RISINGPRICESOFESSENTIALITEMS', 'MALFUNCTIONINGINMARKETINGOFPACKAGEDFOODPRODUCTS', 'HOARDINGANDBLACKMARKETINGOFESSENTIALCOMMODITIES', 'NEGATIVEINFLATIONANDRISEINPRICESOFESSENTIALGOODS', 'UNHYGIENICPACKAGEDDRINKINGWATERBOTTLES', 'CREATIONOFSTRATEGICRESERVEOFWHEATANDRICE', 'ADULTERATIONINTOORANDBATRIDAL', 'BLACKMARKETINGANDHOARDINGOFESSENTIALCOMMODITIES', 'SPECULATIVETRADINGOFESSENTIALCOMMODITIES', 'FUNCTIONINGOFCONSUMERCOURTS', 'EFFECTSOFRISEINPRICESOFESSENTIALITEMS', 'VIOLATIONOFECBGUIDELINESRELAXATIONOFFISCALCONSOLIDATIONTARGETSOFSTATES', 'EDUCATIONALLOANFAKECURRENCYINATMOFBANKSEMICALCULATIONMETHODSSEPARATIONOFLENDINGBUSINESSFROMINVESTMENTBUSINESSBYBANKS', 'SCRAPPINGOFINSURANCEAGENTSFAKECURRENCYRACKETSATKOLKATASELLINGSTAKESOFPSES', 'DISCUSSIONATGSUMMIT', 'RESTRUCTURINGRURALCREDITDELIVERYSYSTEM', 'COMPENSATIONPAIDBYINSURANCECOMPANIES', 'MERGEROFANYONYABANKWITHSARASWATBANK', 'TAXEXEMPTIONFORA', 'P', 'STATESPQRTSDEVEPPMENTFUND', 'SIXTHPAYCOMMISSIONBENEFITSFORPHYSIOTHERAPISTSPROBLEMSOFFARMERSOFMAHARASHTRA', 'MECHANISMTOMONITORTHELINEOFFUNDS', 'SURPLUSFUNDSWITHPSUSINCIRCULATIONOFFAKECURRENCY', 'LOANDISBURSALUNDERSELFEMPLOYMENTSCHEMESCOMMISSIONSTRUCTUREOFINSURANCEAGENTS', 'CREDITTOSMESECTOR', 'COOPERATIVEANDREGIONALRURALBANKS', 'COMMITMENTCHARGESPAIDTOFINANCIALAGENCIESPLANSFORDISINVESTMENTINPSUS', 'MERGEROFSTATEBANKOFINDOREWITHSBIREVIVALSCHEMEFORRURALCOOPERATIVECREDITSTRUCTURENEWSBIBRANCHATJANGLA', 'SHIMLAUSEOFFUNDOBTAINEDBYDISINVE ...

# %%
model = Word2Vec(window = 1, sg = 0, hs = 0,size=10,
                 negative = 10, # for negative sampling
                 alpha=0.2, min_alpha=0.0007,
                 seed = 500,min_count=1)

# %%
model.build_vocab(sentences)

# %%
print('Word2Vec vocabulary:', model.wv.vocab)
# Out:
# Word2Vec vocabulary: {'SPURTINPRICESOFGOLD': <gensim.models.keyedvectors.Vocab object at 0x121F75B0>, 'OPENINGOFTRADECENTRESINLATINAMERICANCOUNTRIES': <gensim.models.keyedvectors.Vocab object at 0x121F71F0>, 'EARLYEXITOFCHINESEBUSINESSMENFROMTRADEFAIR': <gensim.models.keyedvectors.Vocab object at 0x121F7490>, 'DONATIONBYSTCANDMMTCTOSTUDENTWINGSOFPOLITICALPARTIES': <gensim.models.keyedvectors.Vocab object at 0x121F7610>, 'ENVISAGEDEXPORTEARNINGTARGETS': <gensim.models.keyedvectors.Vocab object at 0x121F7650>, 'REQUESTSFORDENOTIFYINGAPPROVEDSEZS': <gensim.models.keyedvectors.Vocab object at 0x121F7690>, 'TRADEBETWEENINDIAANDRUSSIA': <gensim.models.keyedvectors.Vocab object at 0x121F76B0>, 'SEZSINMAHARASHTRA': <gensim.models.keyedvectors.Vocab object at 0x121F76D0>, 'DONATIONBYSTCMMTCTONSUI': <gensim.models.keyedvectors.Vocab object at 0x121F7630>, 'ANTIDUMPINGCASESREGISTEREDBYDGAD': <gensim.models.keyedvectors.Vocab object at 0x121F7670>, 'EXPORTOFRICEANDVEGETABLES': <gensim.models.keyedvectors.Vocab object at 0x121F76F0>, 'MECHANISMTOREGULATEIMPORTEDGMPACKAGEDFOODS': <gensim.models.keyedvectors.Vocab object at 0x121F7710>, 'INDIANPRODUCTSUNCOMPETITIVEINWORLDMARKET': <gensim.models.keyedvectors.Vocab object at 0x121F7730>, 'RELIEFPACKAGETOEXPORTERSEXTENSIONOFTIMETODEVELOPERSOFSEZS': <gensim.models.keyedvectors.Vocab object at 0x121F7750>, 'THMINISTERIALCONFERENCEOFWTOATGENEVA': <gensim.models.keyedvectors.Vocab object at 0x121F7770>, 'SEZSCONVERTEDINTOCOMMERCIALREALESTATEOPERATIONS': <gensim.models.keyedvectors.Vocab object at 0x121F7790>, 'FINANCIALASSISTANCETOTEAEXPORTERS': <gensim.models.keyedvectors.Vocab object at 0x121F77B0>, 'INTERNATIONALPOLICYNETWORKREPORTSONFAKEMEDICINES': <gensim.models.keyedvectors.Vocab object at 0x121F77D0>, 'NEWFOREIGNTRADEPOLICY': <gensim.models.keyedvectors.Vocab object at 0x121F77F0>, 'MINORITYSTATUSFORCENTRALUNIVERSITIES': <gensim.models.keyedvectors.Vocab object at 0x121F7810>, 'MODERNIZATIONOFAUTONOMOUSMINORITYCOLLEGES': <gensim.models.keyedvectors.Vocab object at 0x121F7830>, 'MINIMUMMARKSFORJEE': <gensim.models.keyedvectors.Vocab object at 0x121F7850>, 'SEATSFORDISADVANTAGEDCHILDRENINMINORITYSCHOOLS': <gensim.models.keyedvectors.Vocab object at 0x121F7870>, 'VISVABHARATIUNIVERSITY': <gensim.models.keyedvectors.Vocab object at 0x121F7890>, 'CENTRALUNIVERSITIESINNORTHEASTERNSTATES': <gensim.models.keyedvectors.Vocab object at 0x121F78B0>, 'SETTINGUPOFCENTRALMADARSABOARD': <gensim.models.keyedvectors.Vocab object at 0x121F78D0>, 'CENTRALUNIVERSITYOFKORAPUT': <gensim.models.keyedvectors.Vocab object at 0x121F78F0>, 'INTRODUCTIONOFPOLYMERCURRENCY': <gensim.models.keyedvectors.Vocab object at 0x121F7910>, 'PROMOTIONOFFOREIGNBREEDOFCOWS': <gensim.models.keyedvectors.Vocab object at 0x121F7930>, 'MARINEFISHERIESREGULATIONANDMANAGEMENTACT': <gensim.models.keyedvectors.Vocab object at 0x121F7950>, 'USEOFHORMONEINJECTIONTOINCREASEMILK': <gensim.models.keyedvectors.Vocab object at 0x121F7970>, 'MODELCOLLEGESINEDUCATIONALLYBACKWARDDISTRICTS': <gensim.models.keyedvectors.Vocab object at 0x121F7990>, 'INFORMATIONSOUGHTUNDERRTIACTFROMCHAUDHARYCHARANSINGHUNIVERSITY': <gensim.models.keyedvectors.Vocab object at 0x121F79B0>, 'INTERESTSUBSIDYONEDUCATIONALLOANS': <gensim.models.keyedvectors.Vocab object at 0x121F79D0>, 'IMPACTOFDROUGHTONRABICROP': <gensim.models.keyedvectors.Vocab object at 0x121F79F0>, 'APPOINTMENTOFJUDGESINHIGHERJUDICIARYNATIONALJUDICIALCOMMISSIONCOMPUTERISATIONOFOFFICIALLANGAUGELEGISLATIVECOMMISSIONOFKERALAAPPOINTMENTOFJUDGESSETTINGUPOFEVENINGCOURTSDISEASESINANIMALSCORRUPTIONINDMS': <gensim.models.keyedvectors.Vocab object at 0x121F7A10>, 'PERSONSWITHTECHNICALEDUCATION': <gensim.models.keyedvectors.Vocab object at 0x121F7A30>, 'DAIRYDEVELOPMENTPROJECTSINMADHYAPRADESH': <gensim.models.keyedvectors.Vocab object at 0x121F7A50>, 'SMUGGLINGOFCATTLEDEEPSEAFISHING': <gensim.models.keyedvectors.Vocab object at 0x121F7A70>, 'INSURANCESCHEMEFORFISHERMEN': <gensim.models.keyedvectors.Vocab object at 0 ...

# %%
print('Word2Vec vocabulary:', model.wv.vocab['INCOMETAXSLABSFORINDUSTRIES'].index)
# Out:
# Word2Vec vocabulary: 190

# %%
model.train(sentences, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# (600, 970)

# %%
similar_titles=[]
similar_titles=model.most_similar('INCOMETAXSLABSFORINDUSTRIES')
print(similar_titles)
# Out:
# [('BANNINGCRIMINALSANDCORRUPTSPERSONSFROMELECTIONS', 0.7694000601768494), ('TRADEBETWEENINDIAANDRUSSIA', 0.7536619901657104), ('DISINVESTMENTSINPSUSPENALTYFORREPAYINGLOANINADVANCE', 0.6195030808448792), ('ENVISAGEDEXPORTEARNINGTARGETS', 0.6084926128387451), ('DONATIONBYSTCANDMMTCTOSTUDENTWINGSOFPOLITICALPARTIES', 0.5980116724967957), ('ISSUEOFVOTERIDENTITYCARDS', 0.5798826217651367), ('REMOVALOFTOXICWASTEGENERATEDBYUNIONCARBIDEPRICEVARIATIONOFDRUGSAIDFORBHOPALGASTRAGEDYCOMMONCODEOFETHICSFORPHARMACEUTICALINDUSTRY', 0.5682671070098877), ('UNHYGIENICPACKAGEDDRINKINGWATERBOTTLES', 0.5594140887260437), ('CORPORATELOANSFACILITYFORRURALPEOPLE', 0.5582634210586548), ('STATUSOFLAWCOMMISSIONSREPORTS', 0.52913498878479)]
